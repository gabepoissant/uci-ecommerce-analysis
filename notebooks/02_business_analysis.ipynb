# %% [markdown]
# # Business Analysis

# %% [markdown]
# ## Setup

# %% [markdown]
# #### Import Modules

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from src.metrics import *
from src.viz import *

apply_style()

# %% [markdown]
# #### Load Cleaned Data

# %%
df = pd.read_csv('../data/processed/cleaned_transactions.csv', parse_dates=['InvoiceDate'])

# %% [markdown]
# #### Notes

# %% [markdown]
# - All incomplete periods have been removed from analysis when appropriate.

# %% [markdown]
# ## Business Questions

# %% [markdown]
# ### Time

# %% [markdown]
# #### How has monthly revenue evolved over time?

# %%
data = revenue_by_period(df, 'month')
line_chart(data,'YearMonth','Revenue','Month','Revenue','Revenue by Month')

# %% [markdown]
# - Revenue is stable throughout mid-2010, hovering around £650k for most of the year before rising sharply throughout Q4 where it eventually tops £1.4M in November.
# - Q4 2010 promises to be much more successful than 2009, based on the limited data from each period.
# - This figure suggests strong year-end seasonality.

# %% [markdown]
# #### Is there evidence of seasonality in sales?

# %%
data = revenue_by_period(df, 'season')
plot_bar(data,'SeasonYear','Revenue','Revenue by Season','Season','Revenue (millions)', units='£')

# %% [markdown]
# - Total revenue remains stable throughout Winter, Spring and Summer 2010, with each season just below £2M.
# - Fall gains £1.3M in total revenue compared to the other seasons in 2010, suggesting year-end seasonality.

# %% [markdown]
# #### What is the average order value, and how has it changed?

# %%
aov(df)\
.style.format({'AOV': '£{:,.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_3230f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3230f_level0_col0" class="col_heading level0 col0" >AOV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3230f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3230f_row0_col0" class="data row0 col0" >£411.27</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = aov(df,'month')
line_chart(data,'YearMonth','AOV','Month','Average Order Value','Average Order Value by Month')

# %% [markdown]
# - The overall average order value is £411, and ranges from £313 to £496. Significant dip in revenue observed in May.
# - Modest increases in AOV during Q4 suggests revenue growth during that period comes from more orders, not larger ones.

# %% [markdown]
# ### Customers

# %% [markdown]
# #### What share of revenue comes from repeat customers?

# %%
repeat_customer_revenue(df)
# Out:
# Repeat customers spent £8,176,251 , which represents 94.25% of all sales.

# %% [markdown]
# - Nearly all revenue is attributed to customers who have ordered two or more times.

# %% [markdown]
# #### How concentrated is revenue among customers?

# %%
data = customer_concentration(df).head(25)
plot_bar(data,'CustomerID','Percentage','Revenue Share by Customer','Customer','Percent of Total Revenue')
# Out:
# Note:  20.7% of transactions are excluded due to unknown customers.

# %% [markdown]
# - The largest customer is responsible for 4% of revenue.
# - 15% of all revenue is generated by just 8 customers (≈0.2% of customers), suggesting moderate concentration.

# %% [markdown]
# ### Products

# %% [markdown]
# #### Which products drive the majority of revenue?

# %%
data = product_concentration(df).head(10)
plot_hbar(data,'Percentage','Description','Top Performing Products','Percentage of Revenue','Product', units='%')

# %% [markdown]
# - The highest grossing product is responsible for 1.7% of all revenue.
# - 7.9% of all revenue is generated by the top 10 products (≈0.24% of products), suggesting low concentration.

# %%
product_concentration(df)\
    .head(10).style.format({'Revenue': '£{:,.0f}','Percentage': '{:,.1%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_7cb11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cb11_level0_col0" class="col_heading level0 col0" >StockCode</th>
#       <th id="T_7cb11_level0_col1" class="col_heading level0 col1" >Description</th>
#       <th id="T_7cb11_level0_col2" class="col_heading level0 col2" >Revenue</th>
#       <th id="T_7cb11_level0_col3" class="col_heading level0 col3" >Percentage</th>
#       <th id="T_7cb11_level0_col4" class="col_heading level0 col4" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cb11_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7cb11_row0_col0" class="data row0 col0" >22423</td>
#       <td id="T_7cb11_row0_col1" class="data row0 col1" >REGENCY CAKESTAND 3 TIER</td>
#       <td id="T_7cb11_row0_col2" class="data row0 col2" >£166,215</td>
#       <td id="T_7cb11_row0_col3" class="data row0 col3" >1.7%</td>
#       <td id="T_7cb11_row0_col4" class="data row0 col4" >13395</td>
#     </tr>
#     <tr>
#       <th id="T_7cb11_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7cb11_row1_col0" class="data row1 col0" >85123A</td>
#       <td id="T_7cb11_row1_col1" class="data row1 col1" >WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td id="T_7cb11_row1_col2" class="data row1 col2" >£158,027</td>
#       <td id="T_7cb11_row1_col3" class="data row1 col3" >1.6%</td>
#       <td id="T_7cb11_row1_col4" class="data row1 col4" >58296</td>
#     </tr>
#     <tr>
#       <th id="T_7cb11_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7cb11_row2_col0" class="data row2 col0" >85099B</td>
#       <td id="T_7cb11_row2_col1" class="data row2 col1" >JUMBO BAG RED WHITE SPOTTY </td>
#       <td id="T_7cb11_row2_col2" class="data row2 col2" >£86,391</td>
#       <td id="T_7cb11_row2_col3" class="data row2 col3" >0.9%</td>
#       <td id="T_7cb11_row2_col4" class="data row2 col4" >48478</td>
#     </tr>
#     <tr>
#       <th id="T_7cb11_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7cb11_row3_col0" class="data row3 col0" >84879</td>
#       <td id="T_7cb11_row3_col1" class="data row3 col1" >ASSORTED COLOUR BIRD ORNAMENT</td>
#       <td id="T_7cb11_row3_col2" class="data row3 col2" >£72,361</td>
#       <td id="T_7cb11_row3_col3" class="data row3 col3" >0.8%</td>
#       <td id="T_7cb11_row3_col4" class="data row3 col4" >44915</td>
#     </tr>
#     <tr>
#       <th id="T_7cb11_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7cb11_row4_col0" class="data row4 col0" >22086</td>
#       <td id="T_7cb11_row4_col1" class="data row4 col1" >PAPER CHAIN KIT 50'S CHRISTMAS </td>
#       <td id="T_7cb11_row4_col2" class="data row4 col2" >£58,012</td>
#       <td id="T_7cb11_row4_col3" class="data row4 col3" >0.6%</td>
#       <td id="T_7cb11_row4_col4" class="data row4 col4" >17166</td>
#     </tr>
#     <tr>
#       <th id="T_7cb11_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7cb11_row5_col0" class="data row5 col0" >84347</td>
#       <td id="T_7cb11_row5_col1" class="data row5 col1" >ROTATING SILVER ANGELS T-LIGHT HLDR</td>
#       <td id="T_7cb11_row5_col2" class="data row5 col2" >£46,386</td>
#       <td id="T_7cb11_row5_col3" class="data row5 col3" >0.5%</td>
#       <td id="T_7cb11_row5_col4" class="data row5 col4" >22422</td>
#     </tr>
#     <tr>
#       <th id="T_7cb11_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7cb11_row6_col0" class="data row6 col0" >47566</td>
#       <td id="T_7cb11_row6_col1" class="data row6 col1" >PARTY BUNTING</td>
#       <td id="T_7cb11_row6_col2" class="data row6 col2" >£45,935</td>
#       <td id="T_7cb11_row6_col3" class="data row6 col3" >0.5%</td>
#       <td id="T_7cb11_row6_col4" class="data row6 col4" >9277</td>
#     </tr>
#     <tr>
#       <th id="T_7cb11_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7cb11_row7_col0" class="data row7 col0" >21843</td>
#       <td id="T_7cb11_row7_col1" class="data row7 col1" >RETRO SPOT CAKE STAND</td>
#       <td id="T_7cb11_row7_col2" class="data row7 col2" >£44,773</td>
#       <td id="T_7cb11_row7_col3" class="data row7 col3" >0.5%</td>
#       <td id="T_7cb11_row7_col4" class="data row7 col4" >4233</td>
#     </tr>
#     <tr>
#       <th id="T_7cb11_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7cb11_row8_col0" class="data row8 col0" >48138</td>
#       <td id="T_7cb11_row8_col1" class="data row8 col1" >DOOR MAT UNION FLAG</td>
#       <td id="T_7cb11_row8_col2" class="data row8 col2" >£42,163</td>
#       <td id="T_7cb11_row8_col3" class="data row8 col3" >0.4%</td>
#       <td id="T_7cb11_row8_col4" class="data row8 col4" >6415</td>
#     </tr>
#     <tr>
#       <th id="T_7cb11_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7cb11_row9_col0" class="data row9 col0" >20685</td>
#       <td id="T_7cb11_row9_col1" class="data row9 col1" >RED SPOTTY COIR DOORMAT</td>
#       <td id="T_7cb11_row9_col2" class="data row9 col2" >£39,822</td>
#       <td id="T_7cb11_row9_col3" class="data row9 col3" >0.4%</td>
#       <td id="T_7cb11_row9_col4" class="data row9 col4" >5888</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### What percentage of gross revenue is lost to returns?

# %%
f'{return_percentage(df):.2%}'
# Out:
# '5.75%'

# %% [markdown]
# - 5.75% of gross revenue is lost to returns, falling well within a healthy range.

# %% [markdown]
# #### Which products have disproportionately high return rates?

# %%
data = return_rates(df).head(10)
plot_hbar(data,'ReturnRate','Description','Most Returned Items','Return Rate','Product', units='%')

# %% [markdown]
# - Returns cannot be traced accurately back to their sales due to limited data window.
# - 26 products have a return rate of over 50%, and 69 products have a return rate of over 25%.

# %%
return_rates(df)\
    .head(10).style.format({'Returns': '{:,.0f}','ReturnRate': '{:,.1%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a3e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a3e6_level0_col0" class="col_heading level0 col0" >StockCode</th>
#       <th id="T_6a3e6_level0_col1" class="col_heading level0 col1" >Returns</th>
#       <th id="T_6a3e6_level0_col2" class="col_heading level0 col2" >ItemsSold</th>
#       <th id="T_6a3e6_level0_col3" class="col_heading level0 col3" >ReturnRate</th>
#       <th id="T_6a3e6_level0_col4" class="col_heading level0 col4" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a3e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a3e6_row0_col0" class="data row0 col0" >22638</td>
#       <td id="T_6a3e6_row0_col1" class="data row0 col1" >2,560</td>
#       <td id="T_6a3e6_row0_col2" class="data row0 col2" >2675</td>
#       <td id="T_6a3e6_row0_col3" class="data row0 col3" >95.7%</td>
#       <td id="T_6a3e6_row0_col4" class="data row0 col4" >SET OF 4 NAPKIN CHARMS CROWNS </td>
#     </tr>
#     <tr>
#       <th id="T_6a3e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a3e6_row1_col0" class="data row1 col0" >22640</td>
#       <td id="T_6a3e6_row1_col1" class="data row1 col1" >2,560</td>
#       <td id="T_6a3e6_row1_col2" class="data row1 col2" >2689</td>
#       <td id="T_6a3e6_row1_col3" class="data row1 col3" >95.2%</td>
#       <td id="T_6a3e6_row1_col4" class="data row1 col4" >SET OF 4 NAPKIN CHARMS 3 KEYS </td>
#     </tr>
#     <tr>
#       <th id="T_6a3e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a3e6_row2_col0" class="data row2 col0" >22641</td>
#       <td id="T_6a3e6_row2_col1" class="data row2 col1" >2,560</td>
#       <td id="T_6a3e6_row2_col2" class="data row2 col2" >2724</td>
#       <td id="T_6a3e6_row2_col3" class="data row2 col3" >94.0%</td>
#       <td id="T_6a3e6_row2_col4" class="data row2 col4" >SET OF 4 NAPKIN CHARMS INSTRUMENT</td>
#     </tr>
#     <tr>
#       <th id="T_6a3e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a3e6_row3_col0" class="data row3 col0" >22643</td>
#       <td id="T_6a3e6_row3_col1" class="data row3 col1" >2,560</td>
#       <td id="T_6a3e6_row3_col2" class="data row3 col2" >2794</td>
#       <td id="T_6a3e6_row3_col3" class="data row3 col3" >91.6%</td>
#       <td id="T_6a3e6_row3_col4" class="data row3 col4" >SET OF 4 NAPKIN CHARMS LEAVES   </td>
#     </tr>
#     <tr>
#       <th id="T_6a3e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6a3e6_row4_col0" class="data row4 col0" >22756</td>
#       <td id="T_6a3e6_row4_col1" class="data row4 col1" >5,000</td>
#       <td id="T_6a3e6_row4_col2" class="data row4 col2" >5618</td>
#       <td id="T_6a3e6_row4_col3" class="data row4 col3" >89.0%</td>
#       <td id="T_6a3e6_row4_col4" class="data row4 col4" >LARGE YELLOW BABUSHKA NOTEBOOK </td>
#     </tr>
#     <tr>
#       <th id="T_6a3e6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6a3e6_row5_col0" class="data row5 col0" >85078</td>
#       <td id="T_6a3e6_row5_col1" class="data row5 col1" >2,300</td>
#       <td id="T_6a3e6_row5_col2" class="data row5 col2" >2652</td>
#       <td id="T_6a3e6_row5_col3" class="data row5 col3" >86.7%</td>
#       <td id="T_6a3e6_row5_col4" class="data row5 col4" >SCANDINAVIAN 3 HEARTS NAPKIN RING</td>
#     </tr>
#     <tr>
#       <th id="T_6a3e6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6a3e6_row6_col0" class="data row6 col0" >90162A</td>
#       <td id="T_6a3e6_row6_col1" class="data row6 col1" >145</td>
#       <td id="T_6a3e6_row6_col2" class="data row6 col2" >180</td>
#       <td id="T_6a3e6_row6_col3" class="data row6 col3" >80.6%</td>
#       <td id="T_6a3e6_row6_col4" class="data row6 col4" >ANT SILVER TURQUOISE BOUDICCA RING</td>
#     </tr>
#     <tr>
#       <th id="T_6a3e6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6a3e6_row7_col0" class="data row7 col0" >22758</td>
#       <td id="T_6a3e6_row7_col1" class="data row7 col1" >5,000</td>
#       <td id="T_6a3e6_row7_col2" class="data row7 col2" >6279</td>
#       <td id="T_6a3e6_row7_col3" class="data row7 col3" >79.6%</td>
#       <td id="T_6a3e6_row7_col4" class="data row7 col4" >LARGE PURPLE BABUSHKA NOTEBOOK  </td>
#     </tr>
#     <tr>
#       <th id="T_6a3e6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6a3e6_row8_col0" class="data row8 col0" >22753</td>
#       <td id="T_6a3e6_row8_col1" class="data row8 col1" >5,000</td>
#       <td id="T_6a3e6_row8_col2" class="data row8 col2" >6371</td>
#       <td id="T_6a3e6_row8_col3" class="data row8 col3" >78.5%</td>
#       <td id="T_6a3e6_row8_col4" class="data row8 col4" >SMALL YELLOW BABUSHKA NOTEBOOK </td>
#     </tr>
#     <tr>
#       <th id="T_6a3e6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6a3e6_row9_col0" class="data row9 col0" >22642</td>
#       <td id="T_6a3e6_row9_col1" class="data row9 col1" >2,560</td>
#       <td id="T_6a3e6_row9_col2" class="data row9 col2" >3291</td>
#       <td id="T_6a3e6_row9_col3" class="data row9 col3" >77.8%</td>
#       <td id="T_6a3e6_row9_col4" class="data row9 col4" >SET OF 4 NAPKIN CHARMS STARS   </td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Geography

# %% [markdown]
# #### How is revenue distributed geographically?

# %%
data = revenue_by_country(df).head(6).reset_index()
plot_bar(data,'Country','Percentage','Revenue by Country','Country','Share of Revenue')

# %% [markdown]
# - 86% of all revenue is generated in the U.K.
# - 95% of revenue is generated in Europe.

# %%
revenue_by_country(df).reset_index()\
    .head(10).style.format({'Revenue': '£{:,.0f}','Percentage': '{:,.1%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_067ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_067ac_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_067ac_level0_col1" class="col_heading level0 col1" >Revenue</th>
#       <th id="T_067ac_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_067ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_067ac_row0_col0" class="data row0 col0" >United Kingdom</td>
#       <td id="T_067ac_row0_col1" class="data row0 col1" >£8,256,734</td>
#       <td id="T_067ac_row0_col2" class="data row0 col2" >85.9%</td>
#     </tr>
#     <tr>
#       <th id="T_067ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_067ac_row1_col0" class="data row1 col0" >EIRE</td>
#       <td id="T_067ac_row1_col1" class="data row1 col1" >£357,769</td>
#       <td id="T_067ac_row1_col2" class="data row1 col2" >3.7%</td>
#     </tr>
#     <tr>
#       <th id="T_067ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_067ac_row2_col0" class="data row2 col0" >Netherlands</td>
#       <td id="T_067ac_row2_col1" class="data row2 col1" >£266,188</td>
#       <td id="T_067ac_row2_col2" class="data row2 col2" >2.8%</td>
#     </tr>
#     <tr>
#       <th id="T_067ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_067ac_row3_col0" class="data row3 col0" >Germany</td>
#       <td id="T_067ac_row3_col1" class="data row3 col1" >£183,370</td>
#       <td id="T_067ac_row3_col2" class="data row3 col2" >1.9%</td>
#     </tr>
#     <tr>
#       <th id="T_067ac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_067ac_row4_col0" class="data row4 col0" >France</td>
#       <td id="T_067ac_row4_col1" class="data row4 col1" >£132,366</td>
#       <td id="T_067ac_row4_col2" class="data row4 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <th id="T_067ac_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_067ac_row5_col0" class="data row5 col0" >Denmark</td>
#       <td id="T_067ac_row5_col1" class="data row5 col1" >£50,349</td>
#       <td id="T_067ac_row5_col2" class="data row5 col2" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_067ac_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_067ac_row6_col0" class="data row6 col0" >Sweden</td>
#       <td id="T_067ac_row6_col1" class="data row6 col1" >£49,514</td>
#       <td id="T_067ac_row6_col2" class="data row6 col2" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_067ac_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_067ac_row7_col0" class="data row7 col0" >Spain</td>
#       <td id="T_067ac_row7_col1" class="data row7 col1" >£42,888</td>
#       <td id="T_067ac_row7_col2" class="data row7 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_067ac_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_067ac_row8_col0" class="data row8 col0" >Switzerland</td>
#       <td id="T_067ac_row8_col1" class="data row8 col1" >£41,182</td>
#       <td id="T_067ac_row8_col2" class="data row8 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_067ac_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_067ac_row9_col0" class="data row9 col0" >Australia</td>
#       <td id="T_067ac_row9_col1" class="data row9 col1" >£30,313</td>
#       <td id="T_067ac_row9_col2" class="data row9 col2" >0.3%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Are certain markets growing faster than others?

# %%
data = market_growth(df).reset_index()
plot_hbar(data,'Total_Growth','Country','Market Growth','Growth','Country', units='%')
# Out:
# Note: 32 (20%) countries are excluded due to insufficient revenue.

# %% [markdown]
# - Though markets like Belgium and Sweden show the highest relative growth, their overall market share remains marginal.
# - U.K. growth represents the most significant real increase in revenue by far.
# - France, Germany show 200%+ growth over this period
# - Netherlands and EIRE show steady growth during this period as well.

# %%
market_growth(df)\
    .style.format({'first_revenue': '£{:,.0f}', 'last_revenue': '£{:,.0f}', 'Total_Growth':'{:,.1%}'})
# Out:
# Note: 32 (20%) countries are excluded due to insufficient revenue.
# <style type="text/css">
# </style>
# <table id="T_2ebcd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ebcd_level0_col0" class="col_heading level0 col0" >first_revenue</th>
#       <th id="T_2ebcd_level0_col1" class="col_heading level0 col1" >last_revenue</th>
#       <th id="T_2ebcd_level0_col2" class="col_heading level0 col2" >Total_Growth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ebcd_level0_row0" class="row_heading level0 row0" >Belgium</th>
#       <td id="T_2ebcd_row0_col0" class="data row0 col0" >£288</td>
#       <td id="T_2ebcd_row0_col1" class="data row0 col1" >£4,653</td>
#       <td id="T_2ebcd_row0_col2" class="data row0 col2" >1,517.9%</td>
#     </tr>
#     <tr>
#       <th id="T_2ebcd_level0_row1" class="row_heading level0 row1" >Sweden</th>
#       <td id="T_2ebcd_row1_col0" class="data row1 col0" >£285</td>
#       <td id="T_2ebcd_row1_col1" class="data row1 col1" >£1,534</td>
#       <td id="T_2ebcd_row1_col2" class="data row1 col2" >437.6%</td>
#     </tr>
#     <tr>
#       <th id="T_2ebcd_level0_row2" class="row_heading level0 row2" >France</th>
#       <td id="T_2ebcd_row2_col0" class="data row2 col0" >£5,874</td>
#       <td id="T_2ebcd_row2_col1" class="data row2 col1" >£18,211</td>
#       <td id="T_2ebcd_row2_col2" class="data row2 col2" >210.0%</td>
#     </tr>
#     <tr>
#       <th id="T_2ebcd_level0_row3" class="row_heading level0 row3" >Germany</th>
#       <td id="T_2ebcd_row3_col0" class="data row3 col0" >£9,035</td>
#       <td id="T_2ebcd_row3_col1" class="data row3 col1" >£27,709</td>
#       <td id="T_2ebcd_row3_col2" class="data row3 col2" >206.7%</td>
#     </tr>
#     <tr>
#       <th id="T_2ebcd_level0_row4" class="row_heading level0 row4" >Netherlands</th>
#       <td id="T_2ebcd_row4_col0" class="data row4 col0" >£15,046</td>
#       <td id="T_2ebcd_row4_col1" class="data row4 col1" >£35,630</td>
#       <td id="T_2ebcd_row4_col2" class="data row4 col2" >136.8%</td>
#     </tr>
#     <tr>
#       <th id="T_2ebcd_level0_row5" class="row_heading level0 row5" >United Kingdom</th>
#       <td id="T_2ebcd_row5_col0" class="data row5 col0" >£725,232</td>
#       <td id="T_2ebcd_row5_col1" class="data row5 col1" >£1,227,781</td>
#       <td id="T_2ebcd_row5_col2" class="data row5 col2" >69.3%</td>
#     </tr>
#     <tr>
#       <th id="T_2ebcd_level0_row6" class="row_heading level0 row6" >EIRE</th>
#       <td id="T_2ebcd_row6_col0" class="data row6 col0" >£18,946</td>
#       <td id="T_2ebcd_row6_col1" class="data row6 col1" >£30,221</td>
#       <td id="T_2ebcd_row6_col2" class="data row6 col2" >59.5%</td>
#     </tr>
#     <tr>
#       <th id="T_2ebcd_level0_row7" class="row_heading level0 row7" >Spain</th>
#       <td id="T_2ebcd_row7_col0" class="data row7 col0" >£7,754</td>
#       <td id="T_2ebcd_row7_col1" class="data row7 col1" >£5,902</td>
#       <td id="T_2ebcd_row7_col2" class="data row7 col2" >-23.9%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Recommendations
#
# - Organize around seasonality. Order volume increases significantly in advance of Q4, and resources should be allocated accordingly.
# - Protect high-value customers. Due to significant customer concentration, care must be taken to maintain good relationships with key clients.
# - Review high-return products. Consider discontinuing SKUs with over 25% return rate, as they account for just 1.6% of all products.
# - Focus on emerging markets. Though the majority of revenue is generated in the U.K., nearby markets such as France and Germany show promise.
